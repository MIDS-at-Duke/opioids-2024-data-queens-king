# %% [markdown]
# # Importing relevant packages

# %%
import pandas as pd
import numpy as np
import warnings

pd.set_option("mode.copy_on_write", True)

# %% [markdown]
# # Reading and Loading (Takes 10 minutes to get relevant states)

# %%
# reading a small sample
all = pd.read_csv(
    "~/Desktop/arcos_all_washpost.zip",
    nrows=200,
    delimiter="\t",
    compression="zip",
)
all.head(5)
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT         REPORTER_NAME  \
# 0       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 1       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 2       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 3       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 4       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
#
#    REPORTER_ADDL_CO_INFO      REPORTER_ADDRESS1  REPORTER_ADDRESS2  \
# 0                    NaN  DBA MCKESSON DRUG CO.  3000 KENSKILL AVE
# 1                    NaN  DBA MCKESSON DRUG CO.  3000 KENSKILL AVE
# 2                    NaN  DBA MCKESSON DRUG CO.  3000 KENSKILL AVE
# 3                    NaN  DBA MCKESSON DRUG CO.  3000 KENSKILL AVE
# 4                    NaN  DBA MCKESSON DRUG CO.  3000 KENSKILL AVE
#
#          REPORTER_CITY REPORTER_STATE  REPORTER_ZIP REPORTER_COUNTY  ...  \
# 0  WASHINGTON CT HOUSE             OH         43160         FAYETTE  ...
# 1  WASHINGTON CT HOUSE             OH         43160         FAYETTE  ...
# 2  WASHINGTON CT HOUSE             OH         43160         FAYETTE  ...
# 3  WASHINGTON CT HOUSE             OH         43160         FAYETTE  ...
# 4  WASHINGTON CT HOUSE             OH         43160         FAYETTE  ...
#
#      DRUG_NAME Measure MME_Conversion_Factor Dosage_Strength TRANSACTION_DATE  \
# 0    OXYCODONE     TAB                   1.5            10.0       2011-02-08
# 1  HYDROCODONE     TAB                   1.0             7.5       2011-03-07
# 2    OXYCODONE     TAB                   1.5            10.0       2011-03-10
# 3  HYDROCODONE     TAB                   1.0             5.0       2011-04-05
# 4  HYDROCODONE     TAB                   1.0             5.0       2011-04-06
#
#       Combined_Labeler_Name       Reporter_family CALC_BASE_WT_IN_GM  \
# 0  Par Pharmaceutical, Inc.  McKesson Corporation            0.89650
# 1                SpecGx LLC  McKesson Corporation            0.45405
# 2  Par Pharmaceutical, Inc.  McKesson Corporation            3.58600
# 3                SpecGx LLC  McKesson Corporation            1.51350
# 4                SpecGx LLC  McKesson Corporation            0.30270
#
#    DOSAGE_UNIT      MME
# 0        100.0  1344.75
# 1        100.0   454.05
# 2        400.0  5379.00
# 3        500.0  1513.50
# 4        100.0   302.70
#
# [5 rows x 33 columns]

# %%
# Columns to keep
variables_to_keep = [
    "BUYER_STATE",
    "BUYER_COUNTY",
    "DRUG_NAME",
    "TRANSACTION_DATE",
    "CALC_BASE_WT_IN_GM",
    "MME_Conversion_Factor",
]

# Chunking
chunk_size = 100000
chunk_list = []
states_to_keep = ["FL", "WA", "OR", "GA", "OK", "AL", "CO", "ME"]


# Read in chunks, filtering for Texas and relevant columns
for chunk in pd.read_csv(
    "~/Desktop/arcos_all_washpost.zip",
    delimiter="\t",
    chunksize=chunk_size,
    compression="zip",
    usecols=variables_to_keep,
):
    filtered_chunk = chunk[chunk["BUYER_STATE"].isin(states_to_keep)]
    chunk_list.append(filtered_chunk)
df = pd.concat(chunk_list, ignore_index=True)
df
# Out:
#          BUYER_STATE BUYER_COUNTY    DRUG_NAME  MME_Conversion_Factor  \
# 0                 GA     RICHMOND    OXYCODONE                    1.5
# 1                 GA       COWETA    OXYCODONE                    1.5
# 2                 GA       CLARKE  HYDROCODONE                    1.0
# 3                 GA    WHITFIELD  HYDROCODONE                    1.0
# 4                 GA         COBB  HYDROCODONE                    1.0
# ...              ...          ...          ...                    ...
# 66662233          ME     KENNEBEC    OXYCODONE                    1.5
# 66662234          ME     KENNEBEC    OXYCODONE                    1.5
# 66662235          ME     KENNEBEC    OXYCODONE                    1.5
# 66662236          ME     KENNEBEC    OXYCODONE                    1.5
# 66662237          ME     KENNEBEC    OXYCODONE                    1.5
#
#          TRANSACTION_DATE  CALC_BASE_WT_IN_GM
# 0              2019-06-19            1.344750
# 1              2019-06-21            3.361875
# 2              2019-06-21            2.270250
# 3              2019-06-21            2.270250
# 4              2019-06-21            2.270250
# ...                   ...                 ...
# 66662233       2006-01-12            3.586000
# 66662234       2006-03-01           11.206250
# 66662235       2006-03-15            1.344750
# 66662236       2006-05-24           10.758000
# 66662237       2006-09-27            4.482500
#
# [66662238 rows x 6 columns]

# %%
df_with_na = df[df.isnull().any(axis=1)]
df_with_na
# Out:
#          BUYER_STATE BUYER_COUNTY    DRUG_NAME  MME_Conversion_Factor  \
# 23064093          FL          NaN  HYDROCODONE                    1.0
# 23996263          FL          NaN  HYDROCODONE                    1.0
# 24532643          FL          NaN  HYDROCODONE                    1.0
# 24625178          FL          NaN  HYDROCODONE                    1.0
# 25095157          FL          NaN  HYDROCODONE                    1.0
# 25633942          FL          NaN  HYDROCODONE                    1.0
# 26435057          FL          NaN  HYDROCODONE                    1.0
# 26820801          FL          NaN  HYDROCODONE                    1.0
# 27705106          FL          NaN  HYDROCODONE                    1.0
# 28319707          FL          NaN  HYDROCODONE                    1.0
# 28703796          FL          NaN  HYDROCODONE                    1.0
# 28796108          FL          NaN  HYDROCODONE                    1.0
# 30996769          FL          NaN  HYDROCODONE                    1.0
# 31559821          FL          NaN  HYDROCODONE                    1.0
# 31780405          FL          NaN  HYDROCODONE                    1.0
# 35783829          FL          NaN  HYDROCODONE                    1.0
# 37021324          GA          NaN  HYDROCODONE                    1.0
# 37028153          GA          NaN    OXYCODONE                    1.5
# 37038479          GA          NaN  HYDROCODONE                    1.0
# 37205368          GA          NaN  HYDROCODONE                    1.0
# 37781802          GA          NaN  HYDROCODONE                    1.0
# 37875005          GA          NaN  HYDROCODONE                    1.0
# 38493616          GA          NaN  HYDROCODONE                    1.0
# 38616613          GA          NaN  HYDROCODONE                    1.0
# 38967320          GA          NaN  HYDROCODONE                    1.0
# 39236504          GA          NaN  HYDROCODONE                    1.0
# 39257757          GA          NaN  HYDROCODONE                    1.0
# 39403150          GA          NaN  HYDROCODONE                    1.0
# 39550172          GA          NaN  HYDROCODONE                    1.0
# 39717070          GA          NaN  HYDROCODONE                    1.0
# 39907145          GA          NaN  HYDROCODONE                    1.0
# 40241033          GA          NaN  HYDROCODONE                    1.0
# 40251049          GA          NaN  HYDROCODONE                    1.0
# 40586074          GA          NaN  HYDROCODONE                    1.0
# 40785505          GA          NaN  HYDROCODONE                    1.0
# 40920901          GA          NaN  HYDROCODONE                    1.0
# 41831763          GA          NaN  HYDROCODONE                    1.0
# 41981475          GA          NaN  HYDROCODONE                    1.0
# 41988364          GA          NaN  HYDROCODONE                    1.0
# 41998333          GA          NaN  HYDROCODONE                    1.0
# 42475931          GA          NaN  HYDROCODONE                    1.0
# 42497091          GA          NaN  HYDROCODONE                    1.0
# 42830825          GA          NaN  HYDROCODONE                    1.0
# 42919436          GA          NaN  HYDROCODONE                    1.0
# 43252357          GA          NaN  HYDROCODONE                    1.0
# 43516993          GA          NaN  HYDROCODONE                    1.0
# 43886488          GA          NaN  HYDROCODONE                    1.0
# 44330181          GA          NaN  HYDROCODONE                    1.0
# 44330182          GA          NaN  HYDROCODONE                    1.0
# 44440271          GA          NaN    OXYCODONE                    1.5
# 44497035          GA          NaN  HYDROCODONE                    1.0
# 45112027          GA          NaN  HYDROCODONE                    1.0
# 45547274          GA          NaN  HYDROCODONE                    1.0
# 45703589          GA          NaN  HYDROCODONE                    1.0
#
#          TRANSACTION_DATE  CALC_BASE_WT_IN_GM
# 23064093       2007-02-12             0.30270
# 23996263       2006-10-12             0.30270
# 24532643       2006-06-22             0.30270
# 24625178       2007-01-22             0.30270
# 25095157       2007-05-14             0.30270
# 25633942       2007-04-02             0.30270
# 26435057       2007-06-07             0.30270
# 26820801       2006-09-07             0.30270
# 27705106       2006-12-06             0.30270
# 28319707       2006-03-02             0.30270
# 28703796       2006-07-06             0.30270
# 28796108       2007-07-30             0.30270
# 30996769       2006-05-18             0.30270
# 31559821       2007-04-12             0.30270
# 31780405       2006-03-28             0.30270
# 35783829       2006-01-30             0.30270
# 37021324       2006-03-20             4.54050
# 37028153       2006-03-01             2.24100
# 37038479       2006-01-25             3.02700
# 37205368       2006-01-25             2.27025
# 37781802       2006-02-01             6.05400
# 37875005       2006-03-22             6.81075
# 38493616       2006-01-23             9.08100
# 38616613       2006-03-20             4.54050
# 38967320       2006-01-11             6.81075
# 39236504       2006-02-21             6.05400
# 39257757       2006-04-05             4.54050
# 39403150       2006-03-29             2.27025
# 39550172       2006-03-30             4.54050
# 39717070       2006-04-05            12.10800
# 39907145       2006-02-15             4.54050
# 40241033       2006-02-15             6.05400
# 40251049       2006-01-16             9.08100
# 40586074       2006-02-27             6.05400
# 40785505       2006-01-12             4.54050
# 40920901       2006-03-21             6.05400
# 41831763       2006-02-02             3.02700
# 41981475       2006-03-20             6.05400
# 41988364       2006-04-19            12.10800
# 41998333       2006-02-02             6.05400
# 42475931       2006-02-01             2.27025
# 42497091       2006-01-25             9.08100
# 42830825       2006-01-25             6.05400
# 42919436       2006-02-22             6.05400
# 43252357       2006-02-22             4.54050
# 43516993       2006-01-05             6.05400
# 43886488       2006-03-09            12.10800
# 44330181       2006-02-21             4.54050
# 44330182       2006-04-04             6.05400
# 44440271       2006-01-04             2.24100
# 44497035       2006-03-21             2.27025
# 45112027       2006-01-12             9.08100
# 45547274       2006-01-05             4.54050
# 45703589       2006-03-30             6.05400

# %% [markdown]
# # Calculating relevant data

# %%
# dropping NAs
all = df[
    df["BUYER_STATE"].isin(["FL", "WA", "OR", "GA", "OK", "AL", "CO", "ME"])
].dropna()
all.head(5)
all
# Out:
#          BUYER_STATE BUYER_COUNTY    DRUG_NAME  MME_Conversion_Factor  \
# 0                 GA     RICHMOND    OXYCODONE                    1.5
# 1                 GA       COWETA    OXYCODONE                    1.5
# 2                 GA       CLARKE  HYDROCODONE                    1.0
# 3                 GA    WHITFIELD  HYDROCODONE                    1.0
# 4                 GA         COBB  HYDROCODONE                    1.0
# ...              ...          ...          ...                    ...
# 66662233          ME     KENNEBEC    OXYCODONE                    1.5
# 66662234          ME     KENNEBEC    OXYCODONE                    1.5
# 66662235          ME     KENNEBEC    OXYCODONE                    1.5
# 66662236          ME     KENNEBEC    OXYCODONE                    1.5
# 66662237          ME     KENNEBEC    OXYCODONE                    1.5
#
#          TRANSACTION_DATE  CALC_BASE_WT_IN_GM
# 0              2019-06-19            1.344750
# 1              2019-06-21            3.361875
# 2              2019-06-21            2.270250
# 3              2019-06-21            2.270250
# 4              2019-06-21            2.270250
# ...                   ...                 ...
# 66662233       2006-01-12            3.586000
# 66662234       2006-03-01           11.206250
# 66662235       2006-03-15            1.344750
# 66662236       2006-05-24           10.758000
# 66662237       2006-09-27            4.482500
#
# [66662184 rows x 6 columns]

# %%
# Getting the year
all["date"] = pd.to_datetime(
    all["TRANSACTION_DATE"], format="%Y-%m-%d", errors="coerce"
)
all["year"] = all["date"].dt.year

all["DRUG_NAME"] = all["DRUG_NAME"].isin(["OXYCODONE", "HYDROCODONE"])

# Make an estimate of total morphine equivalent shipments
all["MME_Conversion_Factor"] = pd.to_numeric(
    all["MME_Conversion_Factor"], errors="coerce"
)
all["morphine_equivalent_g"] = all["CALC_BASE_WT_IN_GM"] * all["MME_Conversion_Factor"]
# Group by year, state, and county, and sum the morphine equivalent shipments
df_grouped = (
    all.groupby(["year", "BUYER_STATE", "BUYER_COUNTY"])
    .morphine_equivalent_g.sum()
    .reset_index()
)
df_grouped
# Out:
#       year BUYER_STATE BUYER_COUNTY  morphine_equivalent_g
# 0     2006          AL      AUTAUGA           17100.542225
# 1     2006          AL      BALDWIN           51039.829050
# 2     2006          AL      BARBOUR            5764.019122
# 3     2006          AL         BIBB            6278.096539
# 4     2006          AL       BLOUNT           10418.423330
# ...    ...         ...          ...                    ...
# 7123  2019          WA    WAHKIAKUM             932.537438
# 7124  2019          WA  WALLA WALLA           13420.082768
# 7125  2019          WA      WHATCOM           40160.700638
# 7126  2019          WA      WHITMAN            7147.307865
# 7127  2019          WA       YAKIMA           54046.172370
#
# [7128 rows x 4 columns]

# %%
# check that the relevant states are in the dataset
assert len(df_grouped["BUYER_STATE"].unique()) == 8
df_grouped.head(5)
# Out:
#    year BUYER_STATE BUYER_COUNTY  morphine_equivalent_g
# 0  2006          AL      AUTAUGA           17100.542225
# 1  2006          AL      BALDWIN           51039.829050
# 2  2006          AL      BARBOUR            5764.019122
# 3  2006          AL         BIBB            6278.096539
# 4  2006          AL       BLOUNT           10418.423330

# %% [markdown]
# # Checking Florida & Constants GA, AL, OK

# %%
florida_and_constants = all[all["BUYER_STATE"].isin(["FL", "AL", "GA", "OK"])]
# florida has 67 counties
assert (
    len(
        florida_and_constants[florida_and_constants["BUYER_STATE"] == "FL"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 67
)
floridacounty = len(
    florida_and_constants[florida_and_constants["BUYER_STATE"] == "FL"][
        "BUYER_COUNTY"
    ].unique()
)
# georgia has 159 counties
assert (
    len(
        florida_and_constants[florida_and_constants["BUYER_STATE"] == "GA"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 159
)
georgiacounty = len(
    florida_and_constants[florida_and_constants["BUYER_STATE"] == "GA"][
        "BUYER_COUNTY"
    ].unique()
)
# oklahoma has 77 counties
assert (
    len(
        florida_and_constants[florida_and_constants["BUYER_STATE"] == "OK"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 77
)
oklahomacounty = len(
    florida_and_constants[florida_and_constants["BUYER_STATE"] == "OK"][
        "BUYER_COUNTY"
    ].unique()
)
# alabama has 67 counties
assert (
    len(
        florida_and_constants[florida_and_constants["BUYER_STATE"] == "AL"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 67
)
alabamacounty = len(
    florida_and_constants[florida_and_constants["BUYER_STATE"] == "AL"][
        "BUYER_COUNTY"
    ].unique()
)
print(florida_and_constants["year"].unique())
print(
    f"Florida has {floridacounty} counties, Georgia has {georgiacounty} counties, Oklahoma has {oklahomacounty} counties, Alabama has {alabamacounty} counties"
)
florida_and_constants.head(5)
# Out:
# [2019 2015 2016 2017 2018 2009 2010 2011 2012 2013 2014 2007 2008 2006]
# Florida has 67 counties, Georgia has 155 counties, Oklahoma has 77 counties, Alabama has 67 counties
#   BUYER_STATE BUYER_COUNTY  DRUG_NAME  MME_Conversion_Factor TRANSACTION_DATE  \
# 0          GA     RICHMOND       True                    1.5       2019-06-19
# 1          GA       COWETA       True                    1.5       2019-06-21
# 2          GA       CLARKE       True                    1.0       2019-06-21
# 3          GA    WHITFIELD       True                    1.0       2019-06-21
# 4          GA         COBB       True                    1.0       2019-06-21
#
#    CALC_BASE_WT_IN_GM       date  year  morphine_equivalent_g
# 0            1.344750 2019-06-19  2019               2.017125
# 1            3.361875 2019-06-21  2019               5.042813
# 2            2.270250 2019-06-21  2019               2.270250
# 3            2.270250 2019-06-21  2019               2.270250
# 4            2.270250 2019-06-21  2019               2.270250

# %% [markdown]
# # Checking Washington & Constants CO, OR, MN

# %%
washington_and_constants = all[all["BUYER_STATE"].isin(["WA", "CO", "OR", "ME"])]
# washington has 39 counties
assert (
    len(
        washington_and_constants[washington_and_constants["BUYER_STATE"] == "WA"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 39
)
washingtoncounty = len(
    washington_and_constants[washington_and_constants["BUYER_STATE"] == "WA"][
        "BUYER_COUNTY"
    ].unique()
)
# colorado has 64 counties
assert (
    len(
        washington_and_constants[washington_and_constants["BUYER_STATE"] == "CO"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 64
)
coloradocounty = len(
    washington_and_constants[washington_and_constants["BUYER_STATE"] == "WA"][
        "BUYER_COUNTY"
    ].unique()
)
# oregon has 36 counties
assert (
    len(
        washington_and_constants[washington_and_constants["BUYER_STATE"] == "OR"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 36
)
# minnesota has 87 counties
assert (
    len(
        washington_and_constants[washington_and_constants["BUYER_STATE"] == "ME"][
            "BUYER_COUNTY"
        ].unique()
    )
    <= 16
)
print(washington_and_constants["year"].unique())
washington_and_constants.head(5)
# Out:
# [2019 2015 2016 2017 2018 2011 2012 2013 2014 2006 2007 2008 2009 2010]
#          BUYER_STATE BUYER_COUNTY  DRUG_NAME  MME_Conversion_Factor  \
# 13052308          WA       BENTON       True                    1.5
# 13052309          WA       BENTON       True                    1.5
# 13052310          WA       BENTON       True                    1.5
# 13052311          WA       BENTON       True                    1.0
# 13052312          WA       BENTON       True                    1.0
#
#          TRANSACTION_DATE  CALC_BASE_WT_IN_GM       date  year  \
# 13052308       2019-07-21            0.672375 2019-07-21  2019
# 13052309       2019-07-21            5.379000 2019-07-21  2019
# 13052310       2019-07-21            1.793000 2019-07-21  2019
# 13052311       2019-07-21            1.513500 2019-07-21  2019
# 13052312       2019-07-21            2.270250 2019-07-21  2019
#
#           morphine_equivalent_g
# 13052308               1.008563
# 13052309               8.068500
# 13052310               2.689500
# 13052311               1.513500
# 13052312               2.270250

# %% [markdown]
# # SAVE TO PARQUET

# %%
# save to parquet
df_grouped.to_parquet("data/opioid_shipment_WA_FL_andconstants.parquet", index=False)
